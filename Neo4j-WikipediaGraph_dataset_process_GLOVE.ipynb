# %%
from py2neo import Graph
from bs4 import BeautifulSoup
import pywikibot
import pandas as pd
import requests
from sklearn.feature_extraction.text import TfidfVectorizer
import wikipedia
import spacy
import os
nlp = spacy.load("en_core_web_sm")
import gensim
from collections import defaultdict
from time import sleep
from gensim.parsing.preprocessing import strip_multiple_whitespaces, preprocess_string, remove_stopwords, strip_tags, strip_punctuation

# %%
#verify if category actually exists on online Wikipedia
def categoryExist(name):
    res = requests.get("https://en.wikipedia.org/wiki/Category:" + name)
    soup = BeautifulSoup(res.content, "html.parser")
    div = soup.find("div", {"id": "mw-normal-catlinks"})
    if(div):
        return True
    else:
        return False

#Use beautifulsoup to scrape the bottom categories of a parent category (these we don't want)
def getBadCategories(parent):
    res = requests.get("https://en.wikipedia.org/wiki/Category:" + parent)
    soup = BeautifulSoup(res.content, "html.parser")
    div = soup.find("div", {"id": "mw-normal-catlinks"})
    if(div):
        to_return = []
        for item in div.findAll("li"):
            to_return.append("_".join(item.get_text().split(" ")))
        return to_return
    else:
        #parent does not exist
        return []

def getSubCategories(name):
    site = pywikibot.Site()
    gen = pywikibot.Category(site,'Category:' + name).subcategories(recurse=False)
    subcats = []
    for item in gen:
        subcats.append("_".join(item.aslink().split(":")[1][:-2].split(" ")))
    return subcats

# %%
blacklist = ["July_events"] #nodes that should not be visited
all_nodes = []
all_relations = [] #child parent
visited = []
def buildGraph(root, path):
    path = path + "/" + root
    print("Current Path: " + path)
    print()
    if((not categoryExist(root)) or (root in blacklist)):
        print("Category DNE or is BLACKLISTED")
        print()
        return
    if(root in visited):
        print("VISITED ALREADY")
        print()
        return
    
    visited.append(root)
    
    #add the node
    all_nodes.append(root)
    
    #get all subcategories
    sub_cat = getSubCategories(root)
    if(len(sub_cat) == 0): #base case
        return

    
    #add all the relationships
    for item in sub_cat:
        #check if this relationship already exists (cycle)
        relation = item + " " + root
        if(relation in all_relations):
            print("Relation already exists: ", relation)
            print()
            return
        all_relations.append(item + " " + root)
   
    #recurse on all sub nodes
    for item in sub_cat:
        buildGraph(item, path)

# %%
buildGraph("Roman_Republic", "")
# Out:
# Current Path: /Roman_Republic
#
# Current Path: /Roman_Republic/Ancient_Roman_Republican_art
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Lists_of_Roman_governors
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Achaea
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Africa
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Arabia_Petraea
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Asia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Bithynia_and_Pontus
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Britain
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Campania
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Cappadocia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Cilicia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Crete_and_Cyrenaica
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Cyprus
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Dacia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Dalmatia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Egypt
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Galatia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Gallia_Aquitania
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Gallia_Belgica
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Gallia_Lugdunensis
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Gallia_Narbonensis
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Gaul
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Gaul/Praetorian_prefects_of_Gaul
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Germania_Inferior
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Germania_Superior
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Hispania
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Hispania/Roman_governors_of_Hispania_Baetica
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Hispania/Roman_governors_of_Hispania_Citerior
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Hispania/Roman_governors_of_Gallaecia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Hispania/Roman_governors_of_Hispania_Tarraconensis
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Hispania_Baetica
#
# VISITED ALREADY
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Judea
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Judea/1st-century_Roman_governors_of_Judea
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Judea/2nd-century_Roman_governors_of_Judea
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Judea/Pontius_Pilate
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Judea/Pontius_Pilate/Cultural_depictions_of_Pontius_Pilate
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Lusitania
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Lycia_et_Pamphylia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Macedonia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Moesia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Lower_Moesia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Upper_Moesia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Pannonia_Inferior
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Pannonia_Superior
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Pannonia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Sardinia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Sicily
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Syria
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Syria/1st-century_BC_Roman_governors_of_Syria
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Syria/1st-century_Roman_governors_of_Syria
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Syria/2nd-century_Roman_governors_of_Syria
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Syria/3rd-century_Roman_governors_of_Syria
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Thracia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Ancient_Roman_governors_by_province/Roman_governors_of_Tuscia_et_Umbria
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Governors_of_the_Anatolic_Theme
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Byzantine_governors_of_Antioch
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Governors_of_the_Armeniac_Theme
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Governors_of_the_Bucellarian_Theme
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Catepans_of_Italy
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Catepans_of_Italy/11th-century_catepans_of_Italy
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Byzantine_governors_of_Chaldia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Governors_of_the_Cibyrrhaeot_Theme
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Byzantine_governors_of_Cyprus
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Despots_of_the_Morea
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Despots_of_the_Morea/14th-century_Despots_of_the_Morea
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Despots_of_the_Morea/15th-century_Despots_of_the_Morea
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Byzantine_governors_of_Dyrrhachium
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Byzantine_governors_of_Epirus
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Exarchs_of_Africa
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Exarchs_of_Ravenna
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Exarchs_of_Ravenna/6th-century_exarchs_of_Ravenna
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Exarchs_of_Ravenna/7th-century_exarchs_of_Ravenna
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Exarchs_of_Ravenna/8th-century_exarchs_of_Ravenna
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Byzantine_governors_of_Hellas
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Byzantine_governors_of_Longobardia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Governors_of_the_Theme_of_Macedonia
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Byzantine_governors_of_the_Peloponnese
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Praetorian_prefects_of_Africa
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Praetorian_prefects_of_the_East
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Praetorian_prefects_of_the_Illyricum
#
# Current Path: /Roman_Republic/Government_of_the_Roman_Republic/Ancient_Roman_governors/Byzantine_governors/Governors_of_the_Theme_of_Samos
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# /anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# /anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-8bd3a5b8ad5a> in <module>
# ----> 1 buildGraph("Roman_Republic", "")
#
# <ipython-input-8-11e110c3c04a> in buildGraph(root, path)
#      39     #recurse on all sub nodes
#      40     for item in sub_cat:
# ---> 41         buildGraph(item, path)
#
# <ipython-input-8-11e110c3c04a> in buildGraph(root, path)
#      39     #recurse on all sub nodes
#      40     for item in sub_cat:
# ---> 41         buildGraph(item, path)
#
# <ipython-input-8-11e110c3c04a> in buildGraph(root, path)
#      39     #recurse on all sub nodes
#      40     for item in sub_cat:
# ---> 41         buildGraph(item, path)
#
# <ipython-input-8-11e110c3c04a> in buildGraph(root, path)
#      39     #recurse on all sub nodes
#      40     for item in sub_cat:
# ---> 41         buildGraph(item, path)
#
# <ipython-input-8-11e110c3c04a> in buildGraph(root, path)
#      22
#      23     #get all subcategories
# ---> 24     sub_cat = getSubCategories(root)
#      25     if(len(sub_cat) == 0): #base case
#      26         return
#
# <ipython-input-2-c12870c1b37b> in getSubCategories(name)
#      52     gen = pywikibot.Category(site,'Category:' + name).subcategories(recurse=False)
#      53     subcats = []
# ---> 54     for item in gen:
#      55         subcats.append("_".join(item.aslink().split(":")[1][:-2].split(" ")))
#      56     return subcats
#
# /anaconda3/lib/python3.6/site-packages/pywikibot/page.py in subcategories(self, recurse, total, content)
#    2852             self._subcats = []
#    2853             for member in self.site.categorymembers(
# -> 2854                     self, member_type='subcat', total=total, content=content):
#    2855                 subcat = Category(member)
#    2856                 self._subcats.append(subcat)
#
# /anaconda3/lib/python3.6/site-packages/pywikibot/data/api.py in __iter__(self)
#    2805                 prev_limit, new_limit, previous_result_had_data)
#    2806             if not hasattr(self, 'data'):
# -> 2807                 self.data = self.request.submit()
#    2808             if not self.data or not isinstance(self.data, dict):
#    2809                 pywikibot.debug(
#
# /anaconda3/lib/python3.6/site-packages/pywikibot/data/api.py in submit(self)
#    1983                                                                    paramstring)
#    1984             rawdata, use_get = self._http_request(use_get, uri, body, headers,
# -> 1985                                                   paramstring)
#    1986             if rawdata is None:
#    1987                 continue
#
# /anaconda3/lib/python3.6/site-packages/pywikibot/data/api.py in _http_request(self, use_get, uri, body, headers, paramstring)
#    1742                 site=self.site, uri=uri,
#    1743                 method='GET' if use_get else 'POST',
# -> 1744                 body=body, headers=headers)
#    1745         except Server504Error:
#    1746             pywikibot.log('Caught HTTP 504 error; retrying')
#
# /anaconda3/lib/python3.6/site-packages/pywikibot/tools/__init__.py in wrapper(*__args, **__kw)
#    1736                              cls, depth)
#    1737                     del __kw[old_arg]
# -> 1738             return obj(*__args, **__kw)
#    1739
#    1740         if not __debug__:
#
# /anaconda3/lib/python3.6/site-packages/pywikibot/comms/http.py in request(site, uri, method, params, body, headers, data, **kwargs)
#     314
#     315     baseuri = site.base_url(uri)
# --> 316     r = fetch(baseuri, method, params, body, headers, **kwargs)
#     317     site.throttle.retry_after = int(r.response_headers.get('retry-after', 0))
#     318     return r.text
#
# /anaconda3/lib/python3.6/site-packages/pywikibot/comms/http.py in fetch(uri, method, params, body, headers, default_error_handling, use_fake_user_agent, data, **kwargs)
#     512             headers['user-agent'] = fake_user_agent()
#     513
# --> 514     request = _enqueue(uri, method, params, body, headers, **kwargs)
#     515     # if there's no data in the answer we're in trouble
#     516     assert request._data is not None
#
# /anaconda3/lib/python3.6/site-packages/pywikibot/comms/http.py in _enqueue(uri, method, params, body, headers, data, **kwargs)
#     468     request = threadedhttp.HttpRequest(
#     469         uri, method, params, body, all_headers, callbacks, **kwargs)
# --> 470     _http_process(session, request)
#     471     return request
#     472
#
# /anaconda3/lib/python3.6/site-packages/pywikibot/comms/http.py in _http_process(session, http_request)
#     381                                    headers=headers, auth=auth, timeout=timeout,
#     382                                    verify=not ignore_validation,
# --> 383                                    **http_request.kwargs)
#     384     except Exception as e:
#     385         http_request.data = e
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /anaconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %%
site = pywikibot.Site('en', 'wikipedia')  # The site we want to run our bot on
#page = pywikibot.Page(site, 'Support_vector_machines')
#page.text

page = wikipedia.page("Markov_networks")
page.content

# %%
fileName = "data/RR"

# %%
#save graph to files
with open(fileName + '_nodes.txt', 'w') as f:
    for item in all_nodes:
        f.write("%s\n" % item)

with open(fileName + '_relations.txt', 'w') as f:
    for item in all_relations:
        f.write("%s\n" % item)

# %%
def fetch_wiki_pages(fileName, pagesToSearch = None):
    wiki_pages_dir = fileName + "_pages"
    if not os.path.exists(wiki_pages_dir):
        os.makedirs(wiki_pages_dir)
    file = open(fileName + '_nodes.txt', "r")
    articles_cleaned = []
    failures = []
    if(pagesToSearch is None):
        pagesToSearch = file
    for line in pagesToSearch:
        line = line.strip()
        wiki_page_path = wiki_pages_dir + "/" + line + ".txt"
        print(wiki_page_path)
        if(os.path.isfile(wiki_page_path)):
            print(wiki_page_path + " already exists")
            continue
        #sleep(10)
        print("fetching ==" + line + "==")
    #     all_good = True
    #     while(True):
        try:
            search = wikipedia.search(line.rstrip("\n"))[0]
            page = wikipedia.page(search)
        except wikipedia.DisambiguationError as e:
            page = wikipedia.page(e.options[0])
        except wikipedia.WikipediaException as e: # search is too busy
            print("ERROR: search too busy")
            failures.append(line)
            continue
            #all_good = False
        except Exception:
            print("ERROR: random error")
            articles_cleaned.append("")
            failures.append(line)
            continue
    #         if all_good:
    #             break;
        #page = wikipedia.page(wikipedia.search(line.rstrip("\n"))[0])
        content = page.content
        
        text_file = open(wiki_page_path, "w")
        text_file.write(content)
        text_file.close()
        print("finished")
    file.close()
    return failures

def preprocess(x):
    x = gensim.utils.simple_preprocess(x)
    x = " ".join(x)
    
    CUSTOM_FILTERS = [lambda x: x.lower(), strip_tags, strip_punctuation, remove_stopwords]
    x = preprocess_string(x, CUSTOM_FILTERS)
    return x

def clean_wiki_pages(fileName):
    wiki_pages_dir = fileName + "_pages"
    articles_cleaned = []
    file = open(fileName + '_nodes.txt', "r")
    FREQ_THRESHOLD = 3
    for line in file:
        line = line.strip()
        wiki_page_path = wiki_pages_dir + "/" + line + ".txt"
        if(not os.path.isfile(wiki_page_path)):
            print("ERROR: " + wiki_page_path + " does not exist")
            articles_cleaned.append("")
            continue
        
        print("cleaning: " + wiki_page_path)
        f = open(wiki_page_path, "r")
        content = f.read()

        cleaned = preprocess(content) #strip punctuations and stopwords and weird characters
        cleaned = " ".join(cleaned)
        doc = nlp(cleaned)
        lemm = [token.lemma_ for token in doc]
        d = defaultdict(int)
        for item in lemm:
            d[item] += 1
        tokens=[key for key,value in d.items() if value>FREQ_THRESHOLD] #all words with frequency of more than some number
        texts = [word for word in lemm if word in tokens]
        texts = " ".join(texts)
        articles_cleaned.append(texts)
    return articles_cleaned

# %%
failures = fetch_wiki_pages(fileName)
print(len(failures))
while(len(failures) > 0):
    failures = fetch_wiki_pages(fileName, failures)
# Out:
# data/RR_pages/Roman_Republic.txt already exists
# data/RR_pages/Ancient_Roman_Republican_art.txt already exists
# data/RR_pages/Government_of_the_Roman_Republic.txt already exists
# data/RR_pages/Ancient_Roman_governors.txt already exists
# data/RR_pages/Ancient_Roman_governors_by_province.txt already exists
# data/RR_pages/Lists_of_Roman_governors.txt already exists
# data/RR_pages/Roman_governors_of_Achaea.txt already exists
# data/RR_pages/Roman_governors_of_Africa.txt already exists
# data/RR_pages/Roman_governors_of_Arabia_Petraea.txt already exists
# data/RR_pages/Roman_governors_of_Asia.txt already exists
# data/RR_pages/Roman_governors_of_Bithynia_and_Pontus.txt already exists
# data/RR_pages/Roman_governors_of_Britain.txt already exists
# data/RR_pages/Roman_governors_of_Campania.txt already exists
# data/RR_pages/Roman_governors_of_Cappadocia.txt already exists
# data/RR_pages/Roman_governors_of_Cilicia.txt already exists
# data/RR_pages/Roman_governors_of_Crete_and_Cyrenaica.txt already exists
# data/RR_pages/Roman_governors_of_Cyprus.txt already exists
# data/RR_pages/Roman_governors_of_Dacia.txt already exists
# data/RR_pages/Roman_governors_of_Dalmatia.txt already exists
# data/RR_pages/Roman_governors_of_Egypt.txt already exists
# data/RR_pages/Roman_governors_of_Galatia.txt already exists
# data/RR_pages/Roman_governors_of_Gallia_Aquitania.txt already exists
# data/RR_pages/Roman_governors_of_Gallia_Belgica.txt already exists
# data/RR_pages/Roman_governors_of_Gallia_Lugdunensis.txt already exists
# data/RR_pages/Roman_governors_of_Gallia_Narbonensis.txt already exists
# data/RR_pages/Roman_governors_of_Gaul.txt already exists
# data/RR_pages/Praetorian_prefects_of_Gaul.txt already exists
# data/RR_pages/Roman_governors_of_Germania_Inferior.txt already exists
# data/RR_pages/Roman_governors_of_Germania_Superior.txt already exists
# data/RR_pages/Roman_governors_of_Hispania.txt already exists
# data/RR_pages/Roman_governors_of_Hispania_Baetica.txt already exists
# data/RR_pages/Roman_governors_of_Hispania_Citerior.txt already exists
# data/RR_pages/Roman_governors_of_Gallaecia.txt already exists
# data/RR_pages/Roman_governors_of_Hispania_Tarraconensis.txt already exists
# data/RR_pages/Roman_governors_of_Judea.txt already exists
# data/RR_pages/1st-century_Roman_governors_of_Judea.txt already exists
# data/RR_pages/2nd-century_Roman_governors_of_Judea.txt already exists
# data/RR_pages/Pontius_Pilate.txt already exists
# data/RR_pages/Cultural_depictions_of_Pontius_Pilate.txt already exists
# data/RR_pages/Roman_governors_of_Lusitania.txt already exists
# data/RR_pages/Roman_governors_of_Lycia_et_Pamphylia.txt already exists
# data/RR_pages/Roman_governors_of_Macedonia.txt already exists
# data/RR_pages/Roman_governors_of_Moesia.txt already exists
# data/RR_pages/Roman_governors_of_Lower_Moesia.txt already exists
# data/RR_pages/Roman_governors_of_Upper_Moesia.txt already exists
# data/RR_pages/Roman_governors_of_Pannonia_Inferior.txt already exists
# data/RR_pages/Roman_governors_of_Pannonia_Superior.txt already exists
# data/RR_pages/Roman_governors_of_Pannonia.txt already exists
# data/RR_pages/Roman_governors_of_Sardinia.txt already exists
# data/RR_pages/Roman_governors_of_Sicily.txt already exists
# data/RR_pages/Roman_governors_of_Syria.txt already exists
# data/RR_pages/1st-century_BC_Roman_governors_of_Syria.txt already exists
# data/RR_pages/1st-century_Roman_governors_of_Syria.txt already exists
# data/RR_pages/2nd-century_Roman_governors_of_Syria.txt already exists
# data/RR_pages/3rd-century_Roman_governors_of_Syria.txt already exists
# data/RR_pages/Roman_governors_of_Thracia.txt already exists
# data/RR_pages/Roman_governors_of_Tuscia_et_Umbria.txt already exists
# data/RR_pages/Byzantine_governors.txt already exists
# data/RR_pages/Governors_of_the_Anatolic_Theme.txt already exists
# data/RR_pages/Byzantine_governors_of_Antioch.txt already exists
# data/RR_pages/Governors_of_the_Armeniac_Theme.txt already exists
# data/RR_pages/Governors_of_the_Bucellarian_Theme.txt already exists
# data/RR_pages/Catepans_of_Italy.txt already exists
# data/RR_pages/11th-century_catepans_of_Italy.txt already exists
# data/RR_pages/Byzantine_governors_of_Chaldia.txt already exists
# data/RR_pages/Governors_of_the_Cibyrrhaeot_Theme.txt already exists
# data/RR_pages/Byzantine_governors_of_Cyprus.txt already exists
# data/RR_pages/Despots_of_the_Morea.txt already exists
# data/RR_pages/14th-century_Despots_of_the_Morea.txt already exists
# data/RR_pages/15th-century_Despots_of_the_Morea.txt already exists
# data/RR_pages/Byzantine_governors_of_Dyrrhachium.txt already exists
# data/RR_pages/Byzantine_governors_of_Epirus.txt already exists
# data/RR_pages/Exarchs_of_Africa.txt already exists
# data/RR_pages/Exarchs_of_Ravenna.txt already exists
# data/RR_pages/6th-century_exarchs_of_Ravenna.txt already exists
# data/RR_pages/7th-century_exarchs_of_Ravenna.txt already exists
# data/RR_pages/8th-century_exarchs_of_Ravenna.txt already exists
# data/RR_pages/Byzantine_governors_of_Hellas.txt already exists
# data/RR_pages/Byzantine_governors_of_Longobardia.txt already exists
# data/RR_pages/Governors_of_the_Theme_of_Macedonia.txt already exists
# data/RR_pages/Byzantine_governors_of_the_Peloponnese.txt already exists
# data/RR_pages/Praetorian_prefects_of_Africa.txt already exists
# data/RR_pages/Praetorian_prefects_of_the_East.txt already exists
# data/RR_pages/Praetorian_prefects_of_the_Illyricum.txt already exists
# data/RR_pages/Governors_of_the_Theme_of_Samos.txt already exists
# data/RR_pages/Byzantine_governors_of_Sicily.txt already exists
# data/RR_pages/Byzantine_governors_of_Thessalonica.txt already exists
# data/RR_pages/Byzantine_governors_of_Thessaly.txt already exists
# data/RR_pages/Governors_of_the_Theme_of_Thrace.txt already exists
# data/RR_pages/Governors_of_the_Thracesian_Theme.txt already exists
# data/RR_pages/Urban_prefects_of_Constantinople.txt already exists
# data/RR_pages/Byzantine_governors_of_Vaspurakan.txt already exists
# data/RR_pages/Ancient_Roman_proconsuls.txt already exists
# data/RR_pages/Imperial_Roman_proconsuls.txt already exists
# data/RR_pages/Ancient_Roman_propraetors.txt already exists
# data/RR_pages/Urban_prefects_of_Rome.txt already exists
# data/RR_pages/Political_office-holders_in_ancient_Rome.txt already exists
# data/RR_pages/Lists_of_office-holders_in_ancient_Rome.txt already exists
# data/RR_pages/Roman_aediles.txt already exists
# data/RR_pages/Roman_censors.txt already exists
# data/RR_pages/Roman_consular_tribunes.txt already exists
# data/RR_pages/Roman_consuls.txt already exists
# data/RR_pages/Consular_diptychs.txt already exists
# data/RR_pages/Imperial_Roman_consuls.txt already exists
# data/RR_pages/Roman_consuls_designate.txt already exists
# data/RR_pages/Suffect_consuls_of_Imperial_Rome.txt already exists
# data/RR_pages/Theodosius_II.txt already exists
# data/RR_pages/Medieval_Roman_consuls.txt already exists
# data/RR_pages/Charlemagne.txt already exists
# data/RR_pages/Cultural_depictions_of_Charlemagne.txt already exists
# data/RR_pages/Family_of_Charlemagne.txt already exists
# data/RR_pages/Children_of_Charlemagne.txt already exists
# data/RR_pages/Concubines_of_Charlemagne.txt already exists
# data/RR_pages/Wives_of_Charlemagne.txt already exists
# data/RR_pages/Roman_Republican_consuls.txt already exists
# data/RR_pages/Roman_consuls_dying_in_year_of_consulship.txt already exists
# data/RR_pages/Ancient_Roman_decemvirs.txt already exists
# data/RR_pages/Ancient_Roman_dictators.txt already exists
# data/RR_pages/Late_Roman_Empire_political_office-holders.txt already exists
# data/RR_pages/Byzantine_titles_and_offices.txt already exists
# data/RR_pages/Manglabitai.txt already exists
# data/RR_pages/Byzantine_administrative_offices.txt already exists
# data/RR_pages/Byzantine_fiscal_offices.txt already exists
# data/RR_pages/Logothetai_ton_oikeiakon.txt already exists
# data/RR_pages/Logothetai_tou_genikou.txt already exists
# data/RR_pages/Orphanotrophoi.txt already exists
# data/RR_pages/Logothetai_tou_dromou.txt already exists
# data/RR_pages/Byzantine_ecclesiastical_titles_and_offices.txt already exists
# data/RR_pages/Byzantine_court_titles.txt already exists
# data/RR_pages/Caesares.txt already exists
# data/RR_pages/Caesars_of_the_Tetrarchy.txt already exists
# data/RR_pages/Despots_(court_title).txt already exists
# data/RR_pages/Despotates.txt already exists
# data/RR_pages/Despotate_of_Epirus.txt already exists
# data/RR_pages/Battles_involving_the_Despotate_of_Epirus.txt already exists
# data/RR_pages/Komnenodoukas_dynasty.txt already exists
# data/RR_pages/Burial_sites_of_the_Komnenodoukas_dynasty.txt already exists
# data/RR_pages/People_of_the_Despotate_of_Epirus.txt already exists
# data/RR_pages/Despots_of_Epirus.txt already exists
# data/RR_pages/13th-century_despots_of_Epirus.txt already exists
# data/RR_pages/14th-century_despots_of_Epirus.txt already exists
# data/RR_pages/15th-century_despots_of_Epirus.txt already exists
# data/RR_pages/Illegitimate_children_of_despots_of_Epirus.txt already exists
# data/RR_pages/Prisoners_and_detainees_of_the_Despotate_of_Epirus.txt already exists
# data/RR_pages/Women_of_the_Despotate_of_Epirus.txt already exists
# data/RR_pages/Consorts_of_Epirus.txt already exists
# data/RR_pages/Despotate_of_the_Morea.txt already exists
# data/RR_pages/Battles_involving_the_Despotate_of_the_Morea.txt already exists
# data/RR_pages/Mystras.txt already exists
# data/RR_pages/People_of_the_Despotate_of_the_Morea.txt already exists
# data/RR_pages/Serbian_Despotate.txt already exists
# data/RR_pages/Branković_dynasty.txt already exists
# data/RR_pages/Burial_sites_of_the_Branković_dynasty.txt already exists
# data/RR_pages/Despots_of_Serbia.txt already exists
# data/RR_pages/People_of_the_Serbian_Despotate.txt already exists
# data/RR_pages/Treaties_of_the_Serbian_Despotate.txt already exists
# data/RR_pages/Kouropalatai.txt already exists
# data/RR_pages/Magistroi.txt already exists
# data/RR_pages/Megaloi_konostauloi.txt already exists
# data/RR_pages/Nobilissimi.txt already exists
# data/RR_pages/Panhypersebastoi.txt already exists
# data/RR_pages/Pinkernai.txt already exists
# data/RR_pages/Protosebastoi.txt already exists
# data/RR_pages/Protospatharioi.txt already exists
# data/RR_pages/Sebastoi.txt already exists
# data/RR_pages/Sebastokrators.txt already exists
# data/RR_pages/Vestarchai.txt already exists
# data/RR_pages/Byzantine_titles_and_offices_reserved_for_eunuchs.txt already exists
# data/RR_pages/Byzantine_imperial_titles.txt already exists
# data/RR_pages/Porphyrogennetoi.txt already exists
# data/RR_pages/Byzantine_judicial_offices.txt already exists
# data/RR_pages/Byzantine_military_offices.txt already exists
# data/RR_pages/Megaloi_doukes.txt already exists
# data/RR_pages/Megaloi_stratopedarchai.txt already exists
# data/RR_pages/Byzantine_palace_offices.txt already exists
# data/RR_pages/Comites.txt already exists
# data/RR_pages/Magistri_officiorum.txt already exists
# data/RR_pages/Patricii.txt already exists
# data/RR_pages/Roman_legates.txt already exists
# data/RR_pages/Ancient_Roman_Masters_of_the_Horse.txt already exists
# data/RR_pages/Pontifices_Maximi_of_the_Roman_Republic.txt already exists
# data/RR_pages/Members_and_leaders_of_the_Praetorian_Guard.txt already exists
# data/RR_pages/Praetorian_prefects.txt already exists
# data/RR_pages/Praetorian_prefects_of_Italy.txt already exists
# data/RR_pages/Roman_praetors.txt already exists
# data/RR_pages/Imperial_Roman_praetors.txt already exists
# data/RR_pages/Roman_Republican_praetors.txt already exists
# data/RR_pages/Ancient_Roman_priests.txt already exists
# data/RR_pages/Roman_augurs.txt already exists
# data/RR_pages/Augurs_of_the_Roman_Republic.txt already exists
# data/RR_pages/Augurs_of_the_Roman_Empire.txt already exists
# data/RR_pages/Ancient_Roman_priestesses.txt already exists
# data/RR_pages/Priestesses_of_the_Roman_Empire.txt already exists
# data/RR_pages/Priestesses_of_the_Roman_Republic.txt already exists
# data/RR_pages/Vestal_Virgins.txt already exists
# data/RR_pages/Priests_of_the_Roman_Empire.txt already exists
# data/RR_pages/Pontifices_Maximi_of_the_Roman_Empire.txt already exists
# data/RR_pages/Priests_of_the_Roman_Republic.txt already exists
# data/RR_pages/Ancient_Roman_religious_titles.txt already exists
# data/RR_pages/Roman_quaestors.txt already exists
# data/RR_pages/Roman_tribunes_of_the_plebs.txt already exists
# data/RR_pages/Ancient_Roman_senators.txt already exists
# data/RR_pages/Senators_of_the_Roman_Empire.txt already exists
# data/RR_pages/Senators_of_the_Kingdom_of_Rome.txt already exists
# data/RR_pages/Senators_of_the_Roman_Republic.txt already exists
# data/RR_pages/Catiline.txt already exists
# data/RR_pages/Cultural_depictions_of_Catiline.txt already exists
# data/RR_pages/First_Triumvirate.txt already exists
# data/RR_pages/Roman_Senate.txt already exists
# data/RR_pages/History_of_the_Roman_Republic.txt already exists
# data/RR_pages/Centuries_in_the_Roman_Republic.txt already exists
# data/RR_pages/Establishments_in_the_Roman_Republic_by_century.txt already exists
# data/RR_pages/1st-century_BC_establishments_in_the_Roman_Republic.txt already exists
# data/RR_pages/2nd-century_BC_establishments_in_the_Roman_Republic.txt already exists
# data/RR_pages/3rd-century_BC_establishments_in_the_Roman_Republic.txt already exists
# data/RR_pages/Gladiatorial_combat.txt already exists
# data/RR_pages/Roman_amphitheatres.txt already exists
# data/RR_pages/Roman_amphitheatres_in_France.txt already exists
# data/RR_pages/Roman_amphitheatres_in_Italy.txt already exists
# data/RR_pages/Amphitheatres_in_Rome.txt already exists
# data/RR_pages/Roman_amphitheaters_in_North_Africa.txt already exists
# data/RR_pages/Roman_amphitheaters_in_Africa_Proconsularis.txt already exists
# data/RR_pages/Roman_amphitheaters_in_Cyrenaica.txt already exists
# data/RR_pages/Roman_amphitheaters_in_Mauretania_Tingitana.txt already exists
# data/RR_pages/Roman_amphitheatres_in_Germany.txt already exists
# data/RR_pages/Roman_amphitheatres_in_Spain.txt already exists
# data/RR_pages/Roman_amphitheatres_in_the_United_Kingdom.txt already exists
# data/RR_pages/Gladiatorial_games_in_fiction.txt already exists
# data/RR_pages/Cultural_depictions_of_Spartacus.txt already exists
# data/RR_pages/Spartacus_music.txt already exists
# data/RR_pages/Novels_about_Spartacus.txt already exists
# data/RR_pages/Spartacus_television_series.txt already exists
# data/RR_pages/Fictional_gladiators.txt already exists
# data/RR_pages/Films_about_gladiatorial_combat.txt already exists
# data/RR_pages/Gladiator_(novel_series).txt already exists
# data/RR_pages/Roman_gladiators.txt already exists
# data/RR_pages/Spartacus.txt already exists
# data/RR_pages/Gladiator_types.txt already exists
# data/RR_pages/4th-century_BC_establishments_in_the_Roman_Republic.txt already exists
# data/RR_pages/1st_century_BC_in_the_Roman_Republic.txt already exists
# data/RR_pages/1st-century_BC_Romans.txt already exists
# data/RR_pages/1st-century_BC_Roman_emperors.txt already exists
# data/RR_pages/1st-century_BC_Roman_women.txt already exists
# data/RR_pages/Wives_of_Julius_Caesar.txt already exists
# data/RR_pages/Cultural_depictions_of_Julius_Caesar's_wives.txt already exists
# data/RR_pages/Cultural_depictions_of_Calpurnia_(wife_of_Caesar).txt already exists
# data/RR_pages/Julius_Caesar_(play).txt already exists
# data/RR_pages/Works_based_on_Julius_Caesar_(play).txt already exists
# data/RR_pages/Films_based_on_Julius_Caesar_(play).txt already exists
# data/RR_pages/Cultural_depictions_of_Cornelia_(wife_of_Caesar).txt already exists
# data/RR_pages/Cultural_depictions_of_Cossutia.txt already exists
# data/RR_pages/Cultural_depictions_of_Pompeia_(wife_of_Caesar).txt already exists
# data/RR_pages/Calpurnia_(wife_of_Caesar).txt already exists
# data/RR_pages/Cornelia_(wife_of_Caesar).txt already exists
# data/RR_pages/Cossutia.txt already exists
# data/RR_pages/Pompeia_(wife_of_Caesar).txt already exists
# data/RR_pages/Servilia.txt already exists
# data/RR_pages/Cultural_depictions_of_Servilia.txt already exists
# data/RR_pages/Family_of_Servilia.txt already exists
# data/RR_pages/Children_of_Servilia.txt already exists
# data/RR_pages/Brutus.txt already exists
# data/RR_pages/Cultural_depictions_of_Marcus_Junius_Brutus_the_Younger.txt already exists
# data/RR_pages/Family_of_Brutus.txt already exists
# data/RR_pages/Husbands_of_Servilia.txt already exists
# data/RR_pages/Works_about_Servilia.txt already exists
# data/RR_pages/Wives_of_Augustus.txt already exists
# data/RR_pages/Livia.txt already exists
# data/RR_pages/Cultural_depictions_of_Livia.txt already exists
# data/RR_pages/I,_Claudius.txt already exists
# data/RR_pages/Ancient_Romans_involved_in_Caesar's_invasions_of_Britain.txt already exists
# data/RR_pages/Assassins_of_Julius_Caesar.txt already exists
# data/RR_pages/Julius_Caesar.txt already exists
# data/RR_pages/Assassination_of_Julius_Caesar.txt already exists
# data/RR_pages/Cultural_depictions_of_the_assassination_of_Julius_Caesar.txt already exists
# data/RR_pages/Paintings_of_the_death_of_Julius_Caesar.txt already exists
# data/RR_pages/Battles_of_Julius_Caesar.txt already exists
# data/RR_pages/Battles_of_Caesar's_Civil_War.txt already exists
# data/RR_pages/Battles_of_the_Gallic_Wars.txt already exists
# data/RR_pages/Caesar's_Civil_War.txt already exists
# data/RR_pages/Caesar's_Civil_War_films.txt already exists
# data/RR_pages/Cultural_depictions_of_Julius_Caesar.txt already exists
# data/RR_pages/Cultural_depictions_of_Julius_Caesar's_mistresses.txt already exists
# data/RR_pages/Cultural_depictions_of_Cleopatra.txt already exists
# data/RR_pages/Depictions_of_Cleopatra_in_comics.txt already exists
# data/RR_pages/Depictions_of_Cleopatra_on_film.txt already exists
# data/RR_pages/Films_based_on_Antony_and_Cleopatra.txt already exists
# data/RR_pages/Depictions_of_Cleopatra_in_literature.txt already exists
# data/RR_pages/Fictional_depictions_of_Cleopatra_in_literature.txt already exists
# data/RR_pages/Depictions_of_Cleopatra_in_music.txt already exists
# data/RR_pages/Depictions_of_Cleopatra_in_opera.txt already exists
# data/RR_pages/Paintings_depicting_Cleopatra.txt already exists
# data/RR_pages/Paintings_of_Julius_Caesar_and_Cleopatra.txt already exists
# data/RR_pages/Depictions_of_Cleopatra_on_stage.txt already exists
# data/RR_pages/Depictions_of_Cleopatra_in_plays.txt already exists
# data/RR_pages/Antony_and_Cleopatra.txt already exists
# data/RR_pages/Works_based_on_Antony_and_Cleopatra.txt already exists
# data/RR_pages/Depictions_of_Cleopatra_on_television.txt already exists
# data/RR_pages/Cultural_depictions_of_Sempronia_(wife_of_Decimus_Brutus).txt already exists
# data/RR_pages/Depictions_of_Julius_Caesar_in_comics.txt already exists
# data/RR_pages/Depictions_of_Julius_Caesar_on_film.txt already exists
# data/RR_pages/Films_about_Julius_Caesar.txt already exists
# data/RR_pages/Depictions_of_Julius_Caesar_in_literature.txt already exists
# data/RR_pages/Fictional_depictions_of_Julius_Caesar_in_literature.txt already exists
# data/RR_pages/Emperor_(novel_series).txt already exists
# data/RR_pages/Masters_of_Rome_series.txt already exists
# data/RR_pages/Depictions_of_Julius_Caesar_in_music.txt already exists
# data/RR_pages/Depictions_of_Julius_Caesar_in_opera.txt already exists
# data/RR_pages/Paintings_depicting_Julius_Caesar.txt already exists
# data/RR_pages/Depictions_of_Julius_Caesar_in_sculptures.txt already exists
# data/RR_pages/Statues_of_Julius_Caesar.txt already exists
# data/RR_pages/Busts_of_Julius_Caesar.txt already exists
# data/RR_pages/Depictions_of_Julius_Caesar_on_stage.txt already exists
# data/RR_pages/Depictions_of_Julius_Caesar_in_plays.txt already exists
# data/RR_pages/Depictions_of_Julius_Caesar_on_television.txt already exists
# data/RR_pages/Depictions_of_Julius_Caesar_in_video_games.txt already exists
# data/RR_pages/Family_of_Julius_Caesar.txt already exists
# data/RR_pages/Children_of_Julius_Caesar.txt already exists
# data/RR_pages/Augustus.txt already exists
# data/RR_pages/Augustan_building_projects.txt already exists
# data/RR_pages/Family_of_Augustus.txt already exists
# data/RR_pages/Children_of_Augustus.txt already exists
# data/RR_pages/Cultural_depictions_of_Julia_the_Elder.txt already exists
# data/RR_pages/Tiberius.txt already exists
# data/RR_pages/Children_of_Tiberius.txt already exists
# data/RR_pages/Germanicus.txt already exists
# data/RR_pages/Children_of_Germanicus.txt already exists
# data/RR_pages/Caligula.txt already exists
# data/RR_pages/Children_of_Caligula.txt already exists
# data/RR_pages/Cultural_depictions_of_Caligula.txt already exists
# data/RR_pages/Depictions_of_Caligula_on_film.txt already exists
# data/RR_pages/Depictions_of_Caligula_in_literature.txt already exists
# data/RR_pages/Fictional_depictions_of_Caligula_in_literature.txt already exists
# data/RR_pages/Depictions_of_Caligula_on_television.txt already exists
# data/RR_pages/Generals_of_Caligula.txt already exists
# data/RR_pages/Wives_of_Caligula.txt already exists
# data/RR_pages/Cultural_depictions_of_Julia_Drusilla.txt already exists
# data/RR_pages/Cultural_depictions_of_Germanicus.txt already exists
# data/RR_pages/Generals_of_Tiberius.txt already exists
# data/RR_pages/Cultural_depictions_of_Tiberius.txt already exists
# data/RR_pages/Wives_of_Tiberius.txt already exists
# data/RR_pages/Generals_of_Augustus.txt already exists
# data/RR_pages/Cultural_depictions_of_Augustus.txt already exists
# data/RR_pages/Augustus_in_Ancient_Roman_sculpture.txt already exists
# data/RR_pages/Depictions_of_Augustus_on_film.txt already exists
# data/RR_pages/Depictions_of_Augustus_in_literature.txt already exists
# data/RR_pages/Fictional_depictions_of_Augustus_in_literature.txt already exists
# data/RR_pages/Depictions_of_Augustus_on_television.txt already exists
# data/RR_pages/Augustan_sculptures.txt already exists
# data/RR_pages/Caesarion.txt already exists
# data/RR_pages/Cultural_depictions_of_Caesarion.txt already exists
# data/RR_pages/Gallic_Wars.txt already exists
# data/RR_pages/People_of_the_Gallic_Wars.txt already exists
# data/RR_pages/Barbarian_people_of_the_Gallic_Wars.txt already exists
# data/RR_pages/Roman_people_of_the_Gallic_Wars.txt already exists
# data/RR_pages/Campaigns_of_the_Gallic_Wars.txt already exists
# data/RR_pages/Caesar's_invasions_of_Britain.txt already exists
# data/RR_pages/Individuals_involved_in_Caesar's_invasions_of_Britain.txt already exists
# data/RR_pages/Briton_kings_involved_in_Caesar's_invasions_of_Britain.txt already exists
# data/RR_pages/Roman_legions_involved_in_Caesar's_invasions_of_Britain.txt already exists
# data/RR_pages/Traditional_history_of_Caesar's_invasions_of_Britain.txt already exists
# data/RR_pages/Tribes_involved_in_Caesar's_invasions_of_Britain.txt already exists
# data/RR_pages/Gallic_Wars_films.txt already exists
# data/RR_pages/Asterix_films.txt already exists
# data/RR_pages/Tribes_involved_in_the_Gallic_Wars.txt already exists
# data/RR_pages/Monuments_and_memorials_to_Julius_Caesar.txt already exists
# data/RR_pages/Things_named_after_Julius_Caesar.txt already exists
# data/RR_pages/Caesars_Entertainment_Corporation.txt already exists
# data/RR_pages/Bally's_Las_Vegas.txt already exists
# data/RR_pages/Caesars_Palace.txt already exists
# data/RR_pages/Alan_King_Tennis_Classic.txt already exists
# data/RR_pages/1976_Alan_King_Tennis_Classic.txt already exists
# data/RR_pages/1977_Alan_King_Tennis_Classic.txt already exists
# data/RR_pages/1978_Alan_King_Tennis_Classic.txt already exists
# data/RR_pages/Albums_recorded_at_Caesars_Palace.txt already exists
# data/RR_pages/Caesars_Palace_Grand_Prix.txt already exists
# data/RR_pages/Caesars_Palace_video_games.txt already exists
# data/RR_pages/World_Series_of_Poker.txt already exists
# data/RR_pages/World_Series_of_Poker_video_games.txt already exists
# data/RR_pages/World_Series_of_Poker_Asia_Pacific.txt already exists
# data/RR_pages/World_Series_of_Poker_bracelet_winners.txt already exists
# data/RR_pages/World_Series_of_Poker_Main_Event_winners.txt already exists
# data/RR_pages/World_Series_of_Poker_Circuit.txt already exists
# data/RR_pages/World_Series_of_Poker_Circuit_event_winners.txt already exists
# data/RR_pages/World_Series_of_Poker_Europe.txt already exists
# data/RR_pages/World_Series_of_Poker_Europe_Main_Event_winners.txt already exists
# data/RR_pages/WSOP_Player_of_the_Year_Award_winners.txt already exists
# data/RR_pages/Julian_calendar.txt already exists
# data/RR_pages/Old_Style_common_years.txt already exists
# data/RR_pages/July.txt already exists
# data/RR_pages/July_in_the_Eastern_Orthodox_calendar.txt already exists
# data/RR_pages/People_associated_with_Julius_Caesar.txt already exists
# data/RR_pages/Lovers_of_Julius_Caesar.txt already exists
# data/RR_pages/Mistresses_of_Julius_Caesar.txt already exists
# data/RR_pages/Cleopatra.txt already exists
# data/RR_pages/Children_of_Cleopatra.txt already exists
# data/RR_pages/Husbands_of_Cleopatra.txt already exists
# data/RR_pages/Works_about_Cleopatra.txt already exists
# data/RR_pages/Military_personnel_of_Julius_Caesar.txt already exists
# data/RR_pages/Works_about_Julius_Caesar.txt already exists
# data/RR_pages/Works_by_Julius_Caesar.txt already exists
# data/RR_pages/Quotes_by_Julius_Caesar.txt already exists
# data/RR_pages/Cato_the_Younger.txt already exists
# data/RR_pages/Cultural_depictions_of_Cato_the_Younger.txt already exists
# data/RR_pages/Catullus.txt already exists
# data/RR_pages/Poetry_by_Catullus.txt already exists
# data/RR_pages/Children_of_Pompey.txt already exists
# data/RR_pages/Cicero.txt already exists
# data/RR_pages/Correspondents_of_Cicero.txt already exists
# data/RR_pages/Cultural_depictions_of_Cicero.txt already exists
# data/RR_pages/Works_about_Cicero.txt already exists
# data/RR_pages/Works_by_Cicero.txt already exists
# data/RR_pages/Orations_of_Cicero.txt already exists
# data/RR_pages/Works_by_Cicero_on_oratory.txt already exists
# data/RR_pages/Philosophical_works_by_Cicero.txt already exists
# data/RR_pages/1st-century_BC_Gallo-Roman_people.txt already exists
# data/RR_pages/Horace.txt already exists
# data/RR_pages/Poetry_by_Horace.txt already exists
# data/RR_pages/Ovid.txt already exists
# data/RR_pages/Adaptations_of_works_by_Ovid.txt already exists
# data/RR_pages/Works_based_on_Metamorphoses.txt already exists
# data/RR_pages/Operas_based_on_Metamorphoses.txt already exists
# data/RR_pages/Poetry_by_Ovid.txt already exists
# data/RR_pages/1st-century_BC_Roman_poets.txt already exists
# data/RR_pages/Virgil.txt already exists
# data/RR_pages/Aeneid.txt already exists
# data/RR_pages/Characters_in_the_Aeneid.txt already exists
# data/RR_pages/Characters_in_Book_VI_of_the_Aeneid.txt already exists
# data/RR_pages/Kings_of_Alba_Longa.txt already exists
# data/RR_pages/Kings_of_Rome.txt already exists
# data/RR_pages/Cultural_depictions_of_Roman_kings.txt already exists
# data/RR_pages/Cultural_depictions_of_Romulus_and_Remus.txt already exists
# data/RR_pages/Cultural_depictions_of_Servius_Tullius.txt already exists
# data/RR_pages/Cultural_depictions_of_Lucius_Tarquinius_Superbus.txt already exists
# data/RR_pages/6th-century_BC_kings_of_Rome.txt already exists
# data/RR_pages/Lucius_Tarquinius_Superbus.txt already exists
# data/RR_pages/Children_of_Lucius_Tarquinius_Superbus.txt already exists
# data/RR_pages/Servius_Tullius.txt already exists
# data/RR_pages/Children_of_Servius_Tullius.txt already exists
# data/RR_pages/7th-century_BC_kings_of_Rome.txt already exists
# data/RR_pages/8th-century_BC_kings_of_Rome.txt already exists
# data/RR_pages/Romulus_and_Remus.txt already exists
# data/RR_pages/Orpheus.txt already exists
# data/RR_pages/Operas_about_Orpheus.txt already exists
# data/RR_pages/Theseus.txt already exists
# data/RR_pages/Cultural_depictions_of_Theseus.txt already exists
# data/RR_pages/Labours_of_Theseus.txt already exists
# data/RR_pages/Offspring_of_Theseus.txt already exists
# data/RR_pages/Deities_in_the_Aeneid.txt already exists
# data/RR_pages/Mars_(mythology).txt already exists
# data/RR_pages/Mars_(mythology)_in_art.txt already exists
# data/RR_pages/Paintings_of_Mars_(mythology).txt already exists
# data/RR_pages/Mercury_(mythology).txt already exists
# data/RR_pages/Temples_of_Mercury.txt already exists
# data/RR_pages/Phoenician_characters_in_the_Aeneid.txt already exists
# data/RR_pages/Works_based_on_the_Aeneid.txt already exists
# data/RR_pages/Cultural_depictions_of_Virgil.txt already exists
# data/RR_pages/Poetry_by_Virgil.txt already exists
# data/RR_pages/Pompey.txt already exists
# data/RR_pages/Cultural_depictions_of_Pompey.txt already exists
# data/RR_pages/Wives_of_Pompey.txt already exists
# data/RR_pages/1st_century_BC_in_Roman_Gaul.txt already exists
# data/RR_pages/1st-century_BC_establishments_in_France.txt already exists
# data/RR_pages/1st_century_BC_in_Hispania.txt already exists
# data/RR_pages/1st-century_BC_establishments_in_Spain.txt already exists
# data/RR_pages/1st_century_BC_in_Italy.txt already exists
# data/RR_pages/1st-century_BC_establishments_in_Italy.txt already exists
# data/RR_pages/1st-century_BC_establishments_in_the_Roman_Empire.txt already exists
# data/RR_pages/0s_establishments_in_the_Roman_Empire.txt already exists
# data/RR_pages/10s_BC_establishments_in_the_Roman_Empire.txt already exists
# data/RR_pages/20s_BC_establishments_in_the_Roman_Empire.txt already exists
# data/RR_pages/1st-century_BC_establishments_in_Roman_Egypt.txt already exists
# data/RR_pages/Mithridatic_Wars.txt already exists
# data/RR_pages/1st-century_BC_Roman_sculptures.txt already exists
# data/RR_pages/Third_Servile_War.txt already exists
# data/RR_pages/Third_Servile_War_films.txt already exists
# data/RR_pages/2nd_century_BC_in_the_Roman_Republic.txt already exists
# data/RR_pages/2nd-century_BC_Romans.txt already exists
# data/RR_pages/2nd-century_BC_Roman_women.txt already exists
# data/RR_pages/Cimbrian_War.txt already exists
# data/RR_pages/People_of_the_Cimbrian_War.txt already exists
# data/RR_pages/Battles_of_the_Cimbrian_War.txt already exists
# data/RR_pages/2nd_century_BC_in_Hispania.txt already exists
# data/RR_pages/2nd-century_BC_establishments_in_Spain.txt already exists
# data/RR_pages/2nd_century_BC_in_Italy.txt already exists
# data/RR_pages/2nd-century_BC_establishments_in_Italy.txt already exists
# data/RR_pages/Roman–Greek_wars.txt already exists
# data/RR_pages/Roman–Syrian_War.txt already exists
# data/RR_pages/Second_Macedonian_War.txt already exists
# data/RR_pages/Third_Macedonian_War.txt already exists
# data/RR_pages/Third_Punic_War.txt already exists
# data/RR_pages/Battles_of_the_Third_Punic_War.txt already exists
# data/RR_pages/Third_Punic_War_films.txt already exists
# data/RR_pages/3rd_century_BC_in_the_Roman_Republic.txt already exists
# data/RR_pages/3rd-century_BC_Romans.txt already exists
# data/RR_pages/3rd-century_BC_Roman_women.txt already exists
# data/RR_pages/Roman_people_of_the_First_Punic_War.txt already exists
# data/RR_pages/Roman_commanders_of_the_First_Punic_War.txt already exists
# data/RR_pages/Roman_people_of_the_Second_Punic_War.txt already exists
# data/RR_pages/Roman_commanders_of_the_Second_Punic_War.txt already exists
# data/RR_pages/First_Macedonian_War.txt already exists
# data/RR_pages/First_Punic_War.txt already exists
# data/RR_pages/Battles_of_the_First_Punic_War.txt already exists
# data/RR_pages/Naval_battles_of_the_First_Punic_War.txt already exists
# data/RR_pages/People_of_the_First_Punic_War.txt already exists
# data/RR_pages/First_Punic_War_commanders.txt already exists
# data/RR_pages/Carthaginian_commanders_of_the_First_Punic_War.txt already exists
# data/RR_pages/3rd_century_BC_in_Hispania.txt already exists
# data/RR_pages/3rd-century_BC_establishments_in_Spain.txt already exists
# data/RR_pages/Second_Punic_War.txt already exists
# data/RR_pages/Battles_of_the_Second_Punic_War.txt already exists
# data/RR_pages/Naval_battles_of_the_Second_Punic_War.txt already exists
# data/RR_pages/Second_Punic_War_films.txt already exists
# data/RR_pages/People_of_the_Second_Punic_War.txt already exists
# data/RR_pages/Second_Punic_War_commanders.txt already exists
# data/RR_pages/Carthaginian_commanders_of_the_Second_Punic_War.txt already exists
# data/RR_pages/Pyrrhic_War.txt already exists
# data/RR_pages/Battles_of_the_Pyrrhic_War.txt already exists
# data/RR_pages/4th_century_BC_in_the_Roman_Republic.txt already exists
# data/RR_pages/4th-century_BC_Romans.txt already exists
# data/RR_pages/Sicilian_Wars.txt already exists
# data/RR_pages/Battles_of_the_Sicilian_Wars.txt already exists
# data/RR_pages/People_of_the_Sicilian_Wars.txt already exists
# data/RR_pages/5th_century_BC_in_the_Roman_Republic.txt already exists
# data/RR_pages/5th-century_BC_Romans.txt already exists
# data/RR_pages/5th-century_BC_Roman_women.txt already exists
# data/RR_pages/6th_century_BC_in_the_Roman_Republic.txt already exists
# data/RR_pages/6th-century_BC_Romans.txt already exists
# data/RR_pages/6th-century_BC_Roman_women.txt already exists
# data/RR_pages/Battles_involving_the_Roman_Republic.txt already exists
# data/RR_pages/Battles_of_Sulla's_second_civil_war.txt already exists
# data/RR_pages/Battles_of_the_Roman–Parthian_Wars.txt already exists
# data/RR_pages/Naval_battles_of_the_Roman_Republic.txt already exists
# data/RR_pages/Naval_battles_of_the_Punic_Wars.txt already exists
# data/RR_pages/Battles_of_the_Punic_Wars.txt already exists
# data/RR_pages/Battles_of_the_Samnite_Wars.txt already exists
# data/RR_pages/Battles_of_the_Roman_Servile_Wars.txt already exists
# data/RR_pages/Sieges_involving_the_Roman_Republic.txt already exists
# data/RR_pages/Establishments_in_the_Roman_Republic.txt already exists
# data/RR_pages/Wars_involving_the_Roman_Republic.txt already exists
# data/RR_pages/Roman_Republican_civil_wars.txt already exists
# data/RR_pages/Roman_Servile_Wars.txt already exists
# data/RR_pages/Rebel_slaves_in_ancient_Rome.txt already exists
# data/RR_pages/Sulla's_second_civil_war.txt already exists
# data/RR_pages/Roman_conquest_of_Hispania.txt already exists
# data/RR_pages/Battles_of_the_Cantabrian_Wars.txt already exists
# data/RR_pages/Macedonian_Wars.txt already exists
# data/RR_pages/Punic_Wars.txt already exists
# data/RR_pages/Mercenary_War.txt already exists
# data/RR_pages/Battles_of_the_Mercenary_War.txt already exists
# data/RR_pages/Rebellions_against_the_Roman_Republic.txt already exists
# data/RR_pages/Roman–Parthian_Wars.txt already exists
# data/RR_pages/People_of_the_Roman–Parthian_Wars.txt already exists
# data/RR_pages/Roman–Persian_Wars.txt already exists
# data/RR_pages/Battles_of_the_Roman–Persian_Wars.txt already exists
# data/RR_pages/Battles_of_the_Roman–Sasanian_Wars.txt already exists
# data/RR_pages/Battles_of_the_Byzantine–Sasanian_War_of_602–628.txt already exists
# data/RR_pages/Sieges_of_the_Roman–Persian_Wars.txt already exists
# data/RR_pages/Sieges_of_Hatra.txt already exists
# data/RR_pages/Sieges_of_Nisibis.txt already exists
# data/RR_pages/Sieges_of_Petra,_Lazica.txt already exists
# data/RR_pages/People_of_the_Roman–Persian_Wars.txt already exists
# data/RR_pages/People_of_the_Roman–Sasanian_Wars.txt already exists
# data/RR_pages/People_of_the_Byzantine–Sasanian_War_of_602–628.txt already exists
# data/RR_pages/Roman–Sasanian_Wars.txt already exists
# data/RR_pages/Byzantine–Sasanian_War_of_602–628.txt already exists
# data/RR_pages/Sasanian_Egypt.txt already exists
# data/RR_pages/Sasanian_governors_of_Egypt.txt already exists
# data/RR_pages/Anastasian_War.txt already exists
# data/RR_pages/Iberian_War.txt already exists
# data/RR_pages/Julian's_Persian_War.txt already exists
# data/RR_pages/Lazic_War.txt already exists
# data/RR_pages/Samnite_Wars.txt already exists
# data/RR_pages/Military_units_and_formations_of_the_Roman_Republic.txt already exists
# data/RR_pages/Foederati.txt already exists
# data/RR_pages/Suebi.txt already exists
# data/RR_pages/Alemanni.txt already exists
# data/RR_pages/Archaeology_of_Alemannia.txt already exists
# data/RR_pages/Battles_involving_the_Alemanni.txt already exists
# data/RR_pages/Burial_sites_of_the_Alamanni.txt already exists
# data/RR_pages/Burial_sites_of_the_Agilolfings.txt already exists
# data/RR_pages/Alemannic_families.txt already exists
# data/RR_pages/Agilolfings.txt already exists
# data/RR_pages/Bavarian_dynasty.txt already exists
# data/RR_pages/Ahalolfing_dynasty.txt already exists
# data/RR_pages/Hunfridings.txt already exists
# data/RR_pages/Udalriching_dynasty.txt already exists
# data/RR_pages/Alemannic_German_language.txt already exists
# data/RR_pages/Swiss_German_language.txt already exists
# data/RR_pages/Swiss_German-language_films.txt already exists
# data/RR_pages/Swiss-German_surnames.txt already exists
# data/RR_pages/Alemannic_people.txt already exists
# data/RR_pages/Alemannic_rulers.txt already exists
# data/RR_pages/Alemannic_warriors.txt already exists
# data/RR_pages/Alemannic_women.txt already exists
# data/RR_pages/Angles_(people).txt already exists
# data/RR_pages/Anglish_people.txt already exists
# data/RR_pages/Anglish_warriors.txt already exists
# data/RR_pages/Battles_involving_the_Suebi.txt already exists
# data/RR_pages/Hermunduri.txt already exists
# data/RR_pages/Kingdom_of_the_Suebi.txt already exists
# data/RR_pages/Suebian_kings.txt already exists
# data/RR_pages/5th-century_Suebian_kings.txt already exists
# data/RR_pages/6th-century_Suebian_kings.txt already exists
# data/RR_pages/Lombards.txt already exists
# data/RR_pages/Lombard_art.txt already exists
# data/RR_pages/Lombard_architecture.txt already exists
# data/RR_pages/Lombard_books.txt already exists
# data/RR_pages/Lombard_sculpture.txt already exists
# data/RR_pages/Lombard_sculptors.txt already exists
# data/RR_pages/Lombard_sculptures.txt already exists
# data/RR_pages/Battles_involving_the_Lombards.txt already exists
# data/RR_pages/Lombard_families.txt already exists
# data/RR_pages/Burial_sites_of_the_dynasties_of_the_Kingdom_of_the_Lombards.txt already exists
# data/RR_pages/Burial_sites_of_the_Gausian_dynasty.txt already exists
# data/RR_pages/Burial_sites_of_the_Harodingian_dynasty.txt already exists
# data/RR_pages/Gausian_dynasty.txt already exists
# data/RR_pages/Harodingian_dynasty.txt already exists
# fetching ==Herbertien_dynasty==
# ERROR: search too busy
# data/RR_pages/Burial_sites_of_the_Herbertien_dynasty.txt already exists
# data/RR_pages/Lethings.txt already exists
# data/RR_pages/Kingdom_of_the_Lombards.txt already exists
# data/RR_pages/Lombard_kings.txt already exists
# data/RR_pages/Lombard_people.txt already exists
# data/RR_pages/6th-century_Lombard_people.txt already exists
# data/RR_pages/7th-century_Lombard_people.txt already exists
# data/RR_pages/8th-century_Lombard_people.txt already exists
# data/RR_pages/8th-century_dukes_of_Spoleto.txt already exists
# data/RR_pages/9th-century_Lombard_people.txt already exists
# data/RR_pages/9th-century_Germanic_people.txt already exists
# data/RR_pages/9th-century_Danish_people.txt already exists
# data/RR_pages/9th-century_English_people.txt already exists
# data/RR_pages/9th-century_English_clergy.txt already exists
# data/RR_pages/9th-century_English_monarchs.txt already exists
# data/RR_pages/Alfred_the_Great.txt already exists
# data/RR_pages/Cultural_depictions_of_Alfred_the_Great.txt already exists
# data/RR_pages/The_Saxon_Stories.txt already exists
# data/RR_pages/9th-century_English_women.txt already exists
# data/RR_pages/9th-century_English_writers.txt already exists
# data/RR_pages/9th-century_Faroese_people.txt already exists
# data/RR_pages/9th-century_Icelandic_people.txt already exists
# data/RR_pages/9th-century_Icelandic_women.txt already exists
# data/RR_pages/9th-century_Norwegian_people.txt already exists
# data/RR_pages/9th-century_Norwegian_women.txt already exists
# data/RR_pages/9th-century_Norwegian_poets.txt already exists
# data/RR_pages/9th-century_Saxon_people.txt already exists
# data/RR_pages/9th-century_Swedish_people.txt already exists
# data/RR_pages/9th-century_Swedish_women.txt already exists
# data/RR_pages/10th-century_Lombard_people.txt already exists
# data/RR_pages/11th-century_Lombard_people.txt already exists
# data/RR_pages/12th-century_Lombard_people.txt already exists
# data/RR_pages/Counts_of_Capua.txt already exists
# data/RR_pages/Dukes_of_Benevento.txt already exists
# data/RR_pages/Lombard_monks.txt already exists
# data/RR_pages/Princes_of_Benevento.txt already exists
# data/RR_pages/Princes_of_Salerno.txt already exists
# data/RR_pages/Lombard_warriors.txt already exists
# data/RR_pages/Lombard_women.txt already exists
# data/RR_pages/Lombard_princesses.txt already exists
# data/RR_pages/Lombardic_queens_consort.txt already exists
# data/RR_pages/Marcomanni.txt already exists
# data/RR_pages/Marcomannic_people.txt already exists
# data/RR_pages/Quadi.txt already exists
# data/RR_pages/Suebian_people.txt already exists
# data/RR_pages/Warini.txt already exists
# data/RR_pages/Old_Latin_literature.txt already exists
# data/RR_pages/Old_Latin-language_writers.txt already exists
# data/RR_pages/Plays_by_Plautus.txt already exists
# data/RR_pages/Optimates.txt already exists
# data/RR_pages/People_of_the_Roman_Republic.txt already exists
# data/RR_pages/Women_of_the_Roman_Republic.txt already exists
# data/RR_pages/People_executed_by_the_Roman_Republic.txt already exists
# data/RR_pages/Jews_and_Judaism_in_the_Roman_Republic.txt already exists
# data/RR_pages/Hasmonean_Kingdom.txt already exists
# data/RR_pages/Centuries_in_the_Hasmonean_Kingdom.txt already exists
# data/RR_pages/1st_century_BC_in_the_Hasmonean_Kingdom.txt already exists
# data/RR_pages/1st-century_BC_establishments_in_the_Hasmonean_Kingdom.txt already exists
# data/RR_pages/2nd_century_BC_in_the_Hasmonean_Kingdom.txt already exists
# data/RR_pages/2nd-century_BC_disestablishments_in_the_Hasmonean_Kingdom.txt already exists
# data/RR_pages/2nd-century_BC_establishments_in_the_Hasmonean_Kingdom.txt already exists
# data/RR_pages/Maccabean_Revolt.txt already exists
# data/RR_pages/Battles_of_the_Maccabean_Revolt.txt already exists
# data/RR_pages/Maccabees.txt already exists
# data/RR_pages/Books_of_the_Maccabees.txt already exists
# data/RR_pages/Seleucid_people_in_the_books_of_the_Maccabees.txt already exists
# data/RR_pages/Cultural_depictions_of_the_Maccabees.txt already exists
# data/RR_pages/Coins_of_Judea.txt already exists
# data/RR_pages/Disestablishments_in_the_Hasmonean_Kingdom.txt already exists
# data/RR_pages/Hasmonean_dynasty.txt already exists
# data/RR_pages/1st-century_BC_Hasmonean_monarchs.txt already exists
# data/RR_pages/1st-century_BC_Hasmonean_rulers.txt already exists
# data/RR_pages/2nd-century_BC_Hasmonean_monarchs.txt already exists
# data/RR_pages/2nd-century_BC_Hasmonean_rulers.txt already exists
# data/RR_pages/Establishments_in_the_Hasmonean_Kingdom.txt already exists
# data/RR_pages/Wars_involving_the_Hasmonean_Kingdom.txt already exists
# data/RR_pages/Herodian_kingdom.txt already exists
# data/RR_pages/1st_century_BC_in_Judea.txt already exists
# data/RR_pages/1st-century_BC_establishments_in_Judea.txt already exists
# data/RR_pages/Establishments_in_the_Herodian_kingdom.txt already exists
# data/RR_pages/Herodian_Tetrarchy.txt already exists
# data/RR_pages/Establishments_in_the_Herodian_Tetrarchy.txt already exists
# data/RR_pages/Religious_leaders_of_the_Roman_Republic.txt already exists
# data/RR_pages/Republican_era_slaves_and_freedmen.txt already exists
# data/RR_pages/Populares.txt already exists
# data/RR_pages/Provinces_of_the_Roman_Republic.txt already exists
# data/RR_pages/Roman_Achaea.txt already exists
# data/RR_pages/Roman_Athens.txt already exists
# data/RR_pages/Ancient_Roman_buildings_and_structures_in_Greece.txt already exists
# data/RR_pages/Roman-era_Athenians.txt already exists
# data/RR_pages/Roman-era_Athenian_philosophers.txt already exists
# data/RR_pages/Roman-era_Athenian_rhetoricians.txt already exists
# data/RR_pages/Saints_of_Roman_Athens.txt already exists
# data/RR_pages/Roman-era_Athenian_women.txt already exists
# data/RR_pages/Roman-era_philosophers_in_Athens.txt already exists
# data/RR_pages/Neoplatonists_in_Athens.txt already exists
# data/RR_pages/Roman-era_students_in_Athens.txt already exists
# data/RR_pages/Christianity_in_Roman_Achaea.txt already exists
# data/RR_pages/Christianity_in_Roman_Athens.txt already exists
# data/RR_pages/Christianity_in_Roman_Corinth.txt already exists
# data/RR_pages/First_Epistle_to_the_Corinthians.txt already exists
# data/RR_pages/First_Epistle_to_the_Corinthians_chapters.txt already exists
# data/RR_pages/1_Corinthians_13.txt already exists
# data/RR_pages/1_Corinthians_6.txt already exists
# data/RR_pages/1_Corinthians_7.txt already exists
# data/RR_pages/1_Corinthians_15.txt already exists
# data/RR_pages/First_Epistle_to_the_Corinthians_papyri.txt already exists
# data/RR_pages/First_Epistle_to_the_Corinthians_verses.txt already exists
# data/RR_pages/Second_Epistle_to_the_Corinthians.txt already exists
# data/RR_pages/Second_Epistle_to_the_Corinthians_chapters.txt already exists
# data/RR_pages/Second_Epistle_to_the_Corinthians_papyri.txt already exists
# data/RR_pages/Saints_of_Roman_Corinth.txt already exists
# data/RR_pages/Saints_of_Roman_Achaea.txt already exists
# data/RR_pages/Roman_Corinth.txt already exists
# data/RR_pages/Roman-era_Corinthians.txt already exists
# data/RR_pages/Historians_of_Roman_Achaea.txt already exists
# data/RR_pages/Roman_Olympia.txt already exists
# data/RR_pages/Roman-era_Olympic_competitors.txt already exists
# data/RR_pages/Roman_Cilicia.txt already exists
# data/RR_pages/Roman_Egypt.txt already exists
# data/RR_pages/Roman-era_Egyptians.txt already exists
# data/RR_pages/1st-century_people_of_Roman_Egypt.txt already exists
# data/RR_pages/1st-century_Egyptian_women.txt already exists
# data/RR_pages/2nd-century_people_of_Roman_Egypt.txt already exists
# data/RR_pages/3rd-century_people_of_Roman_Egypt.txt already exists
# data/RR_pages/3rd-century_Egyptian_women.txt already exists
# data/RR_pages/4th-century_Egyptian_people.txt already exists
# data/RR_pages/4th-century_Egyptian_women.txt already exists
# data/RR_pages/Hypatia.txt already exists
# data/RR_pages/Biographers_of_Hypatia.txt already exists
# data/RR_pages/Cultural_depictions_of_Hypatia.txt already exists
# data/RR_pages/5th-century_Egyptian_people.txt already exists
# data/RR_pages/5th-century_Egyptian_women.txt already exists
# data/RR_pages/Roman-era_Alexandrians.txt already exists
# data/RR_pages/Jews_of_Roman_Alexandria.txt already exists
# data/RR_pages/Philo.txt already exists
# data/RR_pages/Roman-era_librarians_of_Alexandria.txt already exists
# data/RR_pages/Roman-era_philosophers_in_Alexandria.txt already exists
# data/RR_pages/Saints_from_Roman_Egypt.txt already exists
# data/RR_pages/Centuries_in_Roman_Egypt.txt already exists
# data/RR_pages/1st_century_BC_in_Roman_Egypt.txt already exists
# data/RR_pages/1st_century_in_Roman_Egypt.txt already exists
# data/RR_pages/1st-century_establishments_in_Roman_Egypt.txt already exists
# data/RR_pages/2nd_century_in_Roman_Egypt.txt already exists
# data/RR_pages/2nd-century_establishments_in_Roman_Egypt.txt already exists
# data/RR_pages/3rd_century_in_Roman_Egypt.txt already exists
# data/RR_pages/3rd-century_establishments_in_Roman_Egypt.txt already exists
# data/RR_pages/4th_century_in_Roman_Egypt.txt already exists
# data/RR_pages/4th-century_establishments_in_Roman_Egypt.txt already exists
# data/RR_pages/5th_century_in_Byzantine_Egypt.txt already exists
# data/RR_pages/6th_century_in_Byzantine_Egypt.txt already exists
# data/RR_pages/6th-century_Egyptian_people.txt already exists
# data/RR_pages/7th_century_in_Byzantine_Egypt.txt already exists
# data/RR_pages/Establishments_in_Roman_Egypt_by_century.txt already exists
# data/RR_pages/1st_millennium_in_Roman_Egypt.txt already exists
# data/RR_pages/1st-millennium_establishments_in_Roman_Egypt.txt already exists
# data/RR_pages/Roman_Alexandria.txt already exists
# data/RR_pages/Byzantine_Egypt.txt already exists
# data/RR_pages/Apion_family.txt already exists
# data/RR_pages/Muslim_conquest_of_Egypt.txt already exists
# data/RR_pages/Establishments_in_Roman_Egypt.txt already exists
# data/RR_pages/Flight_into_Egypt_in_art.txt already exists
# data/RR_pages/Oxyrhynchus_papyri.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._I.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._II.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._III.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._IV.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._V.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._VI.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._VII.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._VIII.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._IX.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._X.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._XI.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._XII.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._XIII.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._XV.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._XVIII.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._XXII.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._XXIV.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._XXXIV.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._XLI.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._XLII.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._L.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._LVIII.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._LXIV.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._LXV.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._LXVI.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._LXXI.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._LXXII.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._LXXIII.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._LXXIV.txt already exists
# data/RR_pages/Oxyrhynchus_papyri_vol._LXXVII.txt already exists
# data/RR_pages/Roman_fortifications_in_Egypt.txt already exists
# data/RR_pages/Roman_fortified_camps_in_Egypt.txt already exists
# data/RR_pages/Roman_legionary_fortresses_in_Egypt.txt already exists
# data/RR_pages/Roman_sites_in_Egypt.txt already exists
# data/RR_pages/Aswan.txt already exists
# data/RR_pages/People_from_Aswan.txt already exists
# data/RR_pages/Kom_Ombo.txt already exists
# data/RR_pages/Roman_towns_and_cities_in_Egypt.txt already exists
# data/RR_pages/Gallia_Lugdunensis.txt already exists
# data/RR_pages/Asterix.txt already exists
# data/RR_pages/Asterix_books.txt already exists
# data/RR_pages/Asterix_characters.txt already exists
# data/RR_pages/Video_games_based_on_Asterix.txt already exists
# data/RR_pages/Asterix_images.txt already exists
# data/RR_pages/Roman_fortifications_in_Gallia_Lugdunensis.txt already exists
# data/RR_pages/Germania_Superior.txt already exists
# data/RR_pages/Roman_fortifications_in_Germania_Superior.txt already exists
# data/RR_pages/Roman_Illyria.txt already exists
# data/RR_pages/Roman_Dalmatia.txt already exists
# data/RR_pages/Roman_fortifications_in_Roman_Dalmatia.txt already exists
# data/RR_pages/People_from_Roman_Dalmatia.txt already exists
# data/RR_pages/Praetorian_prefecture_of_Illyricum.txt already exists
# data/RR_pages/Noricum.txt already exists
# data/RR_pages/Roman_fortifications_in_Noricum.txt already exists
# data/RR_pages/Pannonia_Inferior.txt already exists
# data/RR_pages/Ancient_history_of_Vojvodina.txt already exists
# data/RR_pages/Gepids.txt already exists
# data/RR_pages/Gepid_people.txt already exists
# data/RR_pages/Gepid_kings.txt already exists
# data/RR_pages/Gepid_warriors.txt already exists
# data/RR_pages/History_of_Syrmia.txt already exists
# data/RR_pages/Military_Frontier.txt already exists
# data/RR_pages/People_of_the_Military_Frontier.txt already exists
# data/RR_pages/Serbian_Militia.txt already exists
# data/RR_pages/Serbian_Vojvodina.txt already exists
# data/RR_pages/People_of_Serbian_Vojvodina.txt already exists
# data/RR_pages/Voivodeship_of_Serbia_and_Banat_of_Temeschwar.txt already exists
# data/RR_pages/Roman_fortifications_in_Pannonia_Inferior.txt already exists
# data/RR_pages/Lycia.txt already exists
# data/RR_pages/Lycians.txt already exists
# data/RR_pages/Lycian_language.txt already exists
# data/RR_pages/Populated_places_in_ancient_Lycia.txt already exists
# data/RR_pages/Roman_Macedonia.txt already exists
# data/RR_pages/Christianity_in_Roman_Macedonia.txt already exists
# data/RR_pages/Epistle_to_the_Philippians.txt already exists
# data/RR_pages/Epistle_to_the_Philippians_chapters.txt already exists
# data/RR_pages/Epistle_to_the_Philippians_papyri.txt already exists
# data/RR_pages/Saints_of_Roman_Macedonia.txt already exists
# data/RR_pages/Saints_of_Roman_Thessalonica.txt already exists
# data/RR_pages/Government_of_Roman_Macedonia.txt already exists
# data/RR_pages/Politarchs_of_Roman_Thessalonica.txt already exists
# data/RR_pages/Roman-era_Macedonians.txt already exists
# data/RR_pages/Roman-era_Thessalonians.txt already exists
# data/RR_pages/Roman_fortifications_in_Macedonia.txt already exists
# data/RR_pages/Roman_Thessalonica.txt already exists
# data/RR_pages/First_Epistle_to_the_Thessalonians.txt already exists
# data/RR_pages/First_Epistle_to_the_Thessalonians_chapters.txt already exists
# data/RR_pages/First_Epistle_to_the_Thessalonians_papyri.txt already exists
# data/RR_pages/Second_Epistle_to_the_Thessalonians.txt already exists
# data/RR_pages/Second_Epistle_to_the_Thessalonians_chapters.txt already exists
# data/RR_pages/Second_Epistle_to_the_Thessalonians_papyri.txt already exists
# data/RR_pages/Roman_Asia.txt already exists
# data/RR_pages/Roman_fortifications_in_Roman_Asia.txt already exists
# data/RR_pages/Amorium.txt already exists
# data/RR_pages/People_from_Amorium.txt already exists
# data/RR_pages/Reform_in_the_Roman_Republic.txt already exists
# data/RR_pages/Socii.txt already exists
# data/RR_pages/Treaties_of_the_Roman_Republic.txt already exists
# data/RR_pages/Tribes_conquered_by_Roman_republic.txt already exists

# %%
articles_cleaned = clean_wiki_pages(fileName)
print(len(articles_cleaned))
# Out:
# cleaning: data/RR_pages/Roman_Republic.txt
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-91b0c83a8a5c> in <module>
# ----> 1 articles_cleaned = clean_wiki_pages(fileName)
#
# <ipython-input-20-732d424bb491> in clean_wiki_pages(fileName)
#      16         content = f.read()
#      17
# ---> 18         cleaned = preprocess(content) #strip punctuations and stopwords and weird characters
#      19         cleaned = " ".join(cleaned)
#      20         doc = nlp(cleaned)
#
# NameError: name 'preprocess' is not defined

# %%
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform(articles_cleaned)
print(vectorizer.get_feature_names())
print(vectors.shape)

# %%
article_names = []
file = open(fileName + '_nodes.txt', "r")
for line in file:
    article_names.append(line.rstrip("\n"))
file.close()

df = pd.DataFrame(vectors.toarray(), columns=vectorizer.get_feature_names())
df["article_name"] = article_names
#save to a file
df.to_hdf(fileName + "_embeddings.h5", key='df')

data_table = pd.read_hdf(fileName + "_embeddings.h5", 'df')
data_table.loc[data_table["article_name"] == "Charlemagne"]
